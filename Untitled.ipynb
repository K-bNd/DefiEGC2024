# %%
import numpy as np
import datetime
import pandas as pd
from matplotlib import pylab as plt
import os

# %% [markdown]
# # DefiEGC 2024
#
# Avec les données disponibles, nous avons remarqué des pics de paiements
# en Juillet 2015.
#
# Nous allons donc chercher les raisons derrière ce phénomène.

# %%
blk = pd.read_csv('timeseries/global.csv')
blk.plot()
#plt(blk["date"], [blk["nb_payments"]])
# Out:
# <AxesSubplot: >

# %%
df = pd.read_csv('networks/2015-10-10.csv', sep=',')
df
# Out:
#               Source      Target       value  nb_transactions
# 0           71397082         265    24888581                1
# 1         Kraken.com   YoBit.net  1282977300                2
# 2            2042210        1747    32060000                4
# 3      SlushPool.com    29976439  4771405017                1
# 4     AlphaBayMarket    BTCCPool   264522640                1
# ...              ...         ...         ...              ...
# 5818    Hashnest.com    73727964     2630186                1
# 5819        Bter.com        1647   999990000                1
# 5820        71110892    69723200   135581086                1
# 5821         2581739  OkLink.com   374608334                1
# 5822   NucleusMarket  BitPay.com    17233333                1
#
# [5823 rows x 4 columns]

# %%
df = pd.read_csv('timeseries/external.csv', sep=',')
df
# Out:
#      Unnamed: 0        date     PriceUSD      HashRate
# 0          2190  2015-01-02   315.942732  3.333450e+05
# 1          2191  2015-01-03   285.647310  3.272842e+05
# 2          2192  2015-01-04   263.334575  3.474869e+05
# 3          2193  2015-01-05   275.003852  3.151626e+05
# 4          2194  2015-01-06   287.549521  3.192031e+05
# ..          ...         ...          ...           ...
# 906        3096  2017-06-26  2426.365051  5.023770e+06
# 907        3097  2017-06-27  2530.345536  4.634604e+06
# 908        3098  2017-06-28  2562.792264  5.554450e+06
# 909        3099  2017-06-29  2540.443032  4.245439e+06
# 910        3100  2017-06-30  2452.712064  5.448314e+06
#
# [911 rows x 4 columns]

# %%
fix, ax = plt.subplots()

ax.plot(df["date"], df["PriceUSD"])

plt.show()

# %%
df["date"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 df["date"].plot()
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/plotting/_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:327, in MPLPlot.generate(self)
#     325 def generate(self):
# ...
